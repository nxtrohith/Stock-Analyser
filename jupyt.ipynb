# %%
import pandas_datareader as pdr
import datetime

# Set the API key in your session
import os
os.environ['TIINGO_API_KEY'] = '6edd324e5345b0d71cdf56a3163d0a5f05c00c65'

# Set dates
start = datetime.datetime(2024, 1, 1)
end = datetime.datetime(2024, 4, 28)

# Fetch stock data
df = pdr.DataReader('GOOGL', 'tiingo', start, end)

print(df.head())
# Out:
#                                    close      high     low     open    volume  \
# symbol date
# GOOGL  2024-01-02 00:00:00+00:00  138.17  139.4500  136.48  138.550  23711220
#        2024-01-03 00:00:00+00:00  138.92  139.6300  137.08  137.250  24212147
#        2024-01-04 00:00:00+00:00  136.39  139.1600  136.35  138.420  27137735
#        2024-01-05 00:00:00+00:00  135.73  137.1558  135.15  136.745  21661914
#        2024-01-08 00:00:00+00:00  138.84  139.0100  136.26  136.290  21403982
#
#                                     adjClose     adjHigh      adjLow  \
# symbol date
# GOOGL  2024-01-02 00:00:00+00:00  137.504115  138.777946  135.822259
#        2024-01-03 00:00:00+00:00  138.250500  138.957079  136.419368
#        2024-01-04 00:00:00+00:00  135.732693  138.489344  135.692886
#        2024-01-05 00:00:00+00:00  135.075874  136.494803  134.498669
#        2024-01-08 00:00:00+00:00  138.170886  138.340067  135.603320
#
#                                      adjOpen  adjVolume  divCash  splitFactor
# symbol date
# GOOGL  2024-01-02 00:00:00+00:00  137.882283   23711220      0.0          1.0
#        2024-01-03 00:00:00+00:00  136.588549   24212147      0.0          1.0
#        2024-01-04 00:00:00+00:00  137.752910   27137735      0.0          1.0
#        2024-01-05 00:00:00+00:00  136.085982   21661914      0.0          1.0
#        2024-01-08 00:00:00+00:00  135.633175   21403982      0.0          1.0
